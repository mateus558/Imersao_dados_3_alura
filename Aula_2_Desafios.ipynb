# %% [markdown]
# <a href="https://colab.research.google.com/github/mateus558/Imersao_de_dados_alura/blob/main/Aula_2_Desafios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(font_scale=1.2)
url_dados = "https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true"

# %%
dados = pd.read_csv(url_dados, compression='zip')
mapa = {'droga': 'composto'}
dados.rename(columns=mapa, inplace=True)
dados.rename(lambda x: x.replace('-',''), axis=1, inplace=True)
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# # Desafio 01: Ordenar o gráfico countplot

# %%
cod_compostos = dados['composto'].value_counts().sort_values(ascending=False).index[:5]
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=dados.query('composto in @cod_compostos'), x='composto', order=cod_compostos)
ax.set_title("Top 5 compostos")
ax.set_xlabel('Compostos')
ax.set_ylabel('Frequência')
plt.show()

# %% [markdown]
# # Desafio 02: Melhorar a visualização alterando tamanho da fonte.
#
# sns.set(font_size=1.2)

# %% [markdown]
# # Desafio 03: Plotar os histogramas com seaborn

# %%
fig, axs = plt.subplots(1, 2, sharey=True, figsize=(15, 5))
ax1 = sns.histplot(x='g0',data=dados, bins=50, ax=axs[0])
ax1.set_ylabel('Frequência')
ax2 = sns.histplot(x='g19',data=dados, bins=50, ax=axs[1])
fig.suptitle("Comparação entre g0 e g19")
plt.show()

# %% [markdown]
# # Desafio 04: Estudar sobre as estatíticas retornadas no .describe()

# %% [markdown]
# # Desafio 05: Refletir sobre a manipulação do tamanho das visualizações.

# %% [markdown]
# # Desafio 06: Fazer outras análises com o boxplot e até com o histograma.

# %%
fig, axs = plt.subplots(1, 2, sharey=True, figsize=(10, 6))
axs[0].set_title('Com droga')
axs[1].set_title('Com controle')
sns.boxplot(data=dados.query('tratamento == "com_droga"'), x='dose', y='g0',ax=axs[0])
ax = sns.boxplot(data=dados.query('tratamento == "com_controle"'), x='dose', y='g0',ax=axs[1])
ax.set_ylabel("")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=dados, x='tempo', y='g0')
plt.show()

# %% [markdown]
# # Desafio 07: Resumo do que você aprendeu com os dados
